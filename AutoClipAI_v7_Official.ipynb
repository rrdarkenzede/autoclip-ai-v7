# %% [markdown]
# # 🌌 AutoClipAI v7.0 — Official Cloud Edition
# Welcome to the 100% Cloud-native video engine.
#
# ### 🛠️ Configuration
# 1. Go to the **Secrets** (🔑) tab in Colab.
# 2. Add your keys: `GEMINI_API_KEY`, `GOOGLE_DRIVE_CREDENTIALS` (JSON string).
# 3. Run the cells below.

# %%
#@title 🏗️ Setup Environment
import os
from google.colab import drive, userdata

# 1. Mount Drive for persistent storage
drive.mount('/content/drive')

# 2. Clone/Prepare Project (If running from fresh colab)
#!git clone https://github.com/YOUR_REPO/AutoClipAI.git /content/autoclip
#%cd /content/autoclip

# 3. Install Dependencies
# !apt-get install -y ffmpeg
# !pip install -r requirements.txt
# !playwright install chromium

# 4. Inject Secrets to Environment
os.environ['GEMINI_API_KEY'] = userdata.get('GEMINI_API_KEY')
os.environ['GOOGLE_DRIVE_CREDENTIALS'] = userdata.get('GOOGLE_DRIVE_CREDENTIALS')
print("✅ Environment Ready.")

# %%
#@title 🚀 Run AutoClipAI (Full Cycle)
# !python main.py --mode 2

# %%
#@title 📦 Stockpile Management
# Manual mode to check or fill stockpile
mode = "Stockpile Only" #@param ["Full Cycle", "Single URL", "Stockpile Only", "Publish Stockpile"]

choice_map = {"Single URL": "1", "Full Cycle": "2", "Stockpile Only": "4", "Publish Stockpile": "5"}
# !python main.py --mode {choice_map[mode]}
